# %%
from datasets import load_dataset

# Specify the dataset you want to download
dataset_name = "financial_phrasebank"

# Load the dataset
dataset = load_dataset(dataset_name, 'sentences_allagree')
# Out:
# Found cached dataset financial_phrasebank (/Users/carlosvarela/.cache/huggingface/datasets/financial_phrasebank/sentences_allagree/1.0.0/550bde12e6c30e2674da973a55f57edde5181d53f5a5a34c1531c53f93b7e141)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 2264
#     })
# })

# %%
# Access the dataset training split (only one available)
train_data = dataset["train"]

# %%
import pandas as pd
import spacy

# %%
#converting to dataframes for initial exploration:
train_df = pd.DataFrame(train_data)
print('train dataframe info:')
print(train_df.info())
# Out:
# train dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  2264 non-null   object
#  1   label     2264 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 35.5+ KB
# None

# %%
def remove_dups(df):
    
    duplicates = df['sentence'].duplicated()
    if True in duplicates.unique():
        df['sentence'].drop_duplicates()
        print('Duplicates removed')
    else:
        print('No duplicates found')
        
    return df
# Remove duplicates:
remove_dups(train_df)

# Remove special characters and bring to lowercase:
train_df['cleaned title'] = train_df['sentence'].str.lower().str.replace('[0-9\W_]+', ' ', regex=True)
train_df.head(5)
# Out:
# Duplicates removed
#                                             sentence  label  \
# 0  According to Gran , the company has no plans t...      1
# 1  For the last quarter of 2010 , Componenta 's n...      2
# 2  In the third quarter of 2010 , net sales incre...      2
# 3  Operating profit rose to EUR 13.1 mn from EUR ...      2
# 4  Operating profit totalled EUR 21.1 mn , up fro...      2
#
#                                        cleaned title
# 0  according to gran the company has no plans to ...
# 1  for the last quarter of componenta s net sales...
# 2  in the third quarter of net sales increased by...
# 3  operating profit rose to eur mn from eur mn in...
# 4  operating profit totalled eur mn up from eur m...

# %%
from spacy.lang.en.stop_words import STOP_WORDS
# Loading the language model:
nlp = spacy.load("en_core_web_sm")

# Applying model to a dataframe column:
train_df['docs'] = train_df['cleaned title'].apply(nlp)

# Defining a function to remove stop words and punctuations using spacy's assets:
def nlp_tokenizer(doc):
    docs_no_stops = [token.lemma_ for token in doc if token.lemma_ not in STOP_WORDS and not token.is_punct]
    return docs_no_stops

train_df['docs'] = train_df['docs'].apply(nlp_tokenizer)

# %%
train_df.head(10)
# Out:
#                                             sentence  label  \
# 0  According to Gran , the company has no plans t...      1
# 1  For the last quarter of 2010 , Componenta 's n...      2
# 2  In the third quarter of 2010 , net sales incre...      2
# 3  Operating profit rose to EUR 13.1 mn from EUR ...      2
# 4  Operating profit totalled EUR 21.1 mn , up fro...      2
# 5  Finnish Talentum reports its operating profit ...      2
# 6  Clothing retail chain Sepp+ñl+ñ 's sales incre...      2
# 7  Consolidated net sales increased 16 % to reach...      2
# 8  Foundries division reports its sales increased...      2
# 9  HELSINKI ( AFX ) - Shares closed higher , led ...      2
#
#                                        cleaned title  \
# 0  according to gran the company has no plans to ...
# 1  for the last quarter of componenta s net sales...
# 2  in the third quarter of net sales increased by...
# 3  operating profit rose to eur mn from eur mn in...
# 4  operating profit totalled eur mn up from eur m...
# 5  finnish talentum reports its operating profit ...
# 6  clothing retail chain sepp ñl ñ s sales increa...
# 7  consolidated net sales increased to reach eur ...
# 8  foundries division reports its sales increased...
# 9  helsinki afx shares closed higher led by nokia...
#
#                                                 docs
# 0  [accord, gran, company, plan, production, russ...
# 1  [quarter, componenta, s, net, sale, double, eu...
# 2  [quarter, net, sale, increase, eur, mn, operat...
# 3  [operating, profit, rise, eur, mn, eur, mn, co...
# 4  [operate, profit, total, eur, mn, eur, mn, rep...
# 5  [finnish, talentum, report, operating, profit,...
# 6  [clothing, retail, chain, sepp, ñl, ñ, s, sale...
# 7  [consolidated, net, sale, increase, reach, eur...
# 8  [foundry, division, report, sale, increase, eu...
# 9  [helsinki, afx, share, close, higher, lead, no...

# %%
all_results = []

# Extract unique strings with exactly 2 characters and store in the list
for doc in train_df['docs']:
    result = list(set(word for word in doc if len(word) == 2))
    all_results.append(result)

# Print all results
print(all_results)
# Out:
# [[], [], ['mn'], ['mn'], ['mn'], ['mn'], ['ñl', 'mn'], [], ['mn'], [], [], [], ['mn'], [], [], [], [], [], [], [], ['mn'], [], [], [], ['mn'], [], [], ['mn'], [], [], [], [], [], [], [], [], ['bn'], [], [], [], [], [], ['mn'], [], [], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], [], [], [], ['ñl', 'mn'], [], [], [], [], ['mn'], ['mn'], ['ac'], [], [], ['mn'], ['mn'], [], ['mn'], ['mn'], ['mn'], [], ['ac'], [], ['mn'], [], [], [], [], [], [], ['bn'], ['mn'], ['mn'], ['mn'], [], ['mn'], [], ['mn'], ['ls'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['mn'], [], [], [], [], [], [], [], [], [], [], ['se'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['mn'], ['mn'], ['mn'], [], [], [], [], [], [], [], ['vv'], [], [], [], [], [], [], [], ['mn'], ['mn'], ['mn'], ['mn'], ['bn'], ['mn'], ['mn'], ['mn'], [], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], [], [], ['mn'], ['mn'], ['mn'], ['mn'], [], [], [], [], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['ac'], [], [], ['mn'], ['mn'], [], [], [], [], [], [], ['mn'], [], ['mn'], ['ac'], ['ac'], ['mn'], [], [], [], [], ['mn'], [], [], [], ['mn'], ['mn'], [], [], [], [], [], [], [], [], [], ['mn'], [], ['mn'], ['mn'], [], [], [], [], [], [], [], [], ['le'], [], ['mn'], [], ['mn'], ['mn'], [], ['mn'], [], [], [], [], [], [], [], ['mn'], [], [], [], [], [], [], [], [], [], [], ['bn'], [], ['co'], ['st'], [], [], [], ['ag', 'jp', 'co'], [], [], [], [], [], [], [], ['va'], [], ['mr', 'pc'], [], [], [], ['pt'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['mn'], [], [], [], [], [], ['co'], [], [], ['ac'], [], ['mr'], [], ['mn'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['mo', 'eb'], [], [], ['mn'], [], [], ['mn'], [], [], [], [], [], ['mn'], [], [], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], [], [], ['mn'], ['mn'], [], ['mn'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['mn'], ['mn'], ['mn'], ['th', 'mn'], [], ['mn'], ['mn'], [], [], [], [], ['mn'], [], [], [], [], [], ['oy'], [], [], ['mn'], [], [], [], [], ['uk'], [], [], [], [], [], [], ['mn'], [], [], [], [], [], [], [], [], [], ['mn'], [], [], [], [], [], [], [], [], [], ['te'], [], [], [], ['mn'], [], ['ab'], [], ['ab'], [], [], [], [], ['ñl', 'àm'], [], [], [], ['mn'], ['uk'], [], [], [], [], ['st'], [], [], [], ['mn'], ['mn'], ['er', 'mn'], ['mn'], [], [], [], [], ['vr'], [], [], [], [], [], [], ['kd'], ['oy'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['le'], ['ab', 'oy'], [], ['mr'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], 
['ñl', 'àm'], ['mn'], ['hk'], ['va'], ['ñn', 'än', 'oy'], ['eu'], ['st'], ['oy'], ['mn'], ['sa'], ['uk'], ['ii'], ['bn'], ['oy'], ['ag'], ['cs'], ['se'], ['âm'], ['st'], ['kd'], ['co', 'eu'], ['ft'], ['mw'], ['ac'], ['zu'], ['ac'], ['hk'], ['oy', 'ky'], ['ce'], ['nd'], ['ya'], ['ev'], ['cv'], ['kd'], ['tv'], ['ml'], ['mp'], ['rl'], ['bn'], ['op'], ['co'], ['oy'], ['mn'], ['mn'], ['mn'], ['mn'], ['sm'], ['co'], ['ir'], ['oy'], ['mr'], ['pc'], ['ac'], ['dc'], ['ei'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['st'], ['oy'], ['km'], ['op', 'co'], ['mn'], ['bn'], ['ag'], ['bm'], ['mn'], ['cs'], ['mn', 'eq'], ['mn'], ['fl'], ['mn'], ['hk'], ['st'], ['mn'], ['co'], ['mn'], ['mn'], ['lt', 'mn'], ['oy'], ['lg'], ['co'], ['mr'], ['mr'], ['mr'], ['mr'], ['mr'], ['ab', 'oy'], ['ab'], ['mn'], ['mn'], ['oy'], ['ms'], ['mn'], ['bn'], ['mn'], ['mn'], ['cp', 'co'], ['co'], ['ea'], ['rf'], ['mn'], ['sq'], ['ál'], ['mn'], ['mn'], ['mr'], ['oy'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['bn'], ['fh'], ['mn'], ['mn'], ['mn'], ['hk'], ['ab', 'ss'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['lp'], ['se'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['ab', 'oy'], ['st'], ['mr'], ['mr'], ['uk'], ['vr'], ['rs'], ['sq'], ['sq', 'ft'], ['oy'], ['oy'], ['ab'], ['hk'], ['ab', 'oy'], ['de', 'du'], ['sq'], ['sq', 'ft'], ['se', 'oy'], ['st'], ['ac'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mr'], ['mr'], ['mn'], ['ac'], ['ag', 'eu'], ['bo'], ['co'], ['st'], ['de'], ['ab'], ['lp'], ['ii'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['se'], ['mn'], ['ep'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['ep'], ['ep'], ['mn'], ['cs'], ['bn'], ['ac'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], ['mn'], [ ...

# %%
# Filter out strings of two or fewer characters from the lists in the 'docs' column
train_df['docs'] = train_df['docs'].apply(lambda doc: [word for word in doc if len(word) > 2])

# %%
train_df.head(10)
# Out:
#                                             sentence  label  \
# 0  According to Gran , the company has no plans t...      1
# 1  For the last quarter of 2010 , Componenta 's n...      2
# 2  In the third quarter of 2010 , net sales incre...      2
# 3  Operating profit rose to EUR 13.1 mn from EUR ...      2
# 4  Operating profit totalled EUR 21.1 mn , up fro...      2
# 5  Finnish Talentum reports its operating profit ...      2
# 6  Clothing retail chain Sepp+ñl+ñ 's sales incre...      2
# 7  Consolidated net sales increased 16 % to reach...      2
# 8  Foundries division reports its sales increased...      2
# 9  HELSINKI ( AFX ) - Shares closed higher , led ...      2
#
#                                        cleaned title  \
# 0  according to gran the company has no plans to ...
# 1  for the last quarter of componenta s net sales...
# 2  in the third quarter of net sales increased by...
# 3  operating profit rose to eur mn from eur mn in...
# 4  operating profit totalled eur mn up from eur m...
# 5  finnish talentum reports its operating profit ...
# 6  clothing retail chain sepp ñl ñ s sales increa...
# 7  consolidated net sales increased to reach eur ...
# 8  foundries division reports its sales increased...
# 9  helsinki afx shares closed higher led by nokia...
#
#                                                 docs
# 0  [accord, gran, company, plan, production, russ...
# 1  [quarter, componenta, net, sale, double, eur, ...
# 2  [quarter, net, sale, increase, eur, operating,...
# 3  [operating, profit, rise, eur, eur, correspond...
# 4  [operate, profit, total, eur, eur, represent, ...
# 5  [finnish, talentum, report, operating, profit,...
# 6  [clothing, retail, chain, sepp, sale, increase...
# 7  [consolidated, net, sale, increase, reach, eur...
# 8  [foundry, division, report, sale, increase, eu...
# 9  [helsinki, afx, share, close, higher, lead, no...

# %%
processed_df = train_df[['docs','label']]
processed_df
# Out:
#                                                    docs  label
# 0     [accord, gran, company, plan, production, russ...      1
# 1     [quarter, componenta, net, sale, double, eur, ...      2
# 2     [quarter, net, sale, increase, eur, operating,...      2
# 3     [operating, profit, rise, eur, eur, correspond...      2
# 4     [operate, profit, total, eur, eur, represent, ...      2
# ...                                                 ...    ...
# 2259  [operate, result, month, period, decrease, pro...      0
# 2260  [helsinki, thomson, financial, share, cargotec...      0
# 2261  [london, marketwatch, share, price, end, lower...      0
# 2262  [operating, profit, fall, eur, eur, include, v...      0
# 2263  [sale, finland, decrease, january, sale, outsi...      0
#
# [2264 rows x 2 columns]

# %%
processed_df['entities'] = processed_df['docs'].apply(lambda tokens: ' '.join(tokens))
processed_df
# Out:
# /var/folders/p7/0l629d4j6wxccht_62k8btmr0000gn/T/ipykernel_73440/4194252769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processed_df['entities'] = processed_df['docs'].apply(lambda tokens: ' '.join(tokens))
#                                                    docs  label  \
# 0     [accord, gran, company, plan, production, russ...      1
# 1     [quarter, componenta, net, sale, double, eur, ...      2
# 2     [quarter, net, sale, increase, eur, operating,...      2
# 3     [operating, profit, rise, eur, eur, correspond...      2
# 4     [operate, profit, total, eur, eur, represent, ...      2
# ...                                                 ...    ...
# 2259  [operate, result, month, period, decrease, pro...      0
# 2260  [helsinki, thomson, financial, share, cargotec...      0
# 2261  [london, marketwatch, share, price, end, lower...      0
# 2262  [operating, profit, fall, eur, eur, include, v...      0
# 2263  [sale, finland, decrease, january, sale, outsi...      0
#
#                                                entities
# 0     accord gran company plan production russia com...
# 1     quarter componenta net sale double eur eur per...
# 2     quarter net sale increase eur operating profit...
# 3     operating profit rise eur eur corresponding pe...
# 4       operate profit total eur eur represent net sale
# ...                                                 ...
# 2259  operate result month period decrease profit eu...
# 2260  helsinki thomson financial share cargotec fall...
# 2261  london marketwatch share price end lower londo...
# 2262  operating profit fall eur eur include vessel s...
# 2263  sale finland decrease january sale outside fin...
#
# [2264 rows x 3 columns]

# %%
model_df = processed_df[['entities','label']]
model_df
# Out:
#                                                entities  label
# 0     accord gran company plan production russia com...      1
# 1     quarter componenta net sale double eur eur per...      2
# 2     quarter net sale increase eur operating profit...      2
# 3     operating profit rise eur eur corresponding pe...      2
# 4       operate profit total eur eur represent net sale      2
# ...                                                 ...    ...
# 2259  operate result month period decrease profit eu...      0
# 2260  helsinki thomson financial share cargotec fall...      0
# 2261  london marketwatch share price end lower londo...      0
# 2262  operating profit fall eur eur include vessel s...      0
# 2263  sale finland decrease january sale outside fin...      0
#
# [2264 rows x 2 columns]

# %%
model_df.to_csv('sentences_allagree_processed_ver1.2.csv', index = False)
